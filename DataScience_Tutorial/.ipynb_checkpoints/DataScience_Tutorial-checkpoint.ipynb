# %% [markdown]
# <h1><center>CMSC320: Intro to Data Science Tutorial</center></h1>

# %%
import pandas as pd
import numpy as np

# %%
energy_data = pd.read_excel("Table_2.1_Energy_Consumption_by_Sector-2.xlsx", sheetname="Monthly Data", header=10, skiprows=[11])
energy_data.head(5)
# Out:
#        Month  Primary Energy Consumed by the Residential Sector  \
# 0 1973-01-01                                           1313.816
# 1 1973-02-01                                           1150.011
# 2 1973-03-01                                            970.362
# 3 1973-04-01                                            709.631
# 4 1973-05-01                                            544.596
#
#    Total Energy Consumed by the Residential Sector  \
# 0                                         1932.187
# 1                                         1687.255
# 2                                         1497.067
# 3                                         1177.661
# 4                                         1015.008
#
#    Primary Energy Consumed by the Commercial Sector  \
# 0                                           656.607
# 1                                           621.766
# 2                                           490.154
# 3                                           362.003
# 4                                           289.109
#
#    Total Energy Consumed by the Commercial Sector  \
# 0                                        1079.310
# 1                                        1001.920
# 2                                         884.437
# 3                                         735.461
# 4                                         696.114
#
#    Primary Energy Consumed by the Industrial Sector  \
# 0                                          2054.675
# 1                                          1869.459
# 2                                          1944.295
# 3                                          1924.207
# 4                                          2070.447
#
#    Total Energy Consumed by the Industrial Sector  \
# 0                                        2701.524
# 1                                        2460.752
# 2                                        2579.613
# 3                                        2550.210
# 4                                        2741.810
#
#    Primary Energy Consumed by the Transportation Sector  \
# 0                                           1506.380
# 1                                           1439.361
# 2                                           1561.162
# 3                                           1479.971
# 4                                           1621.585
#
#    Total Energy Consumed by the Transportation Sector  \
# 0                                           1509.552
# 1                                           1442.127
# 2                                           1564.016
# 3                                           1482.632
# 4                                           1624.436
#
#    Primary Energy Consumed by the Electric Power Sector  \
# 0                                           1691.096
# 1                                           1511.458
# 2                                           1559.159
# 3                                           1470.152
# 4                                           1551.631
#
#    Energy Consumption Balancing Item  Primary Energy Consumption Total
# 0                              3.693                          7226.265
# 1                              2.654                          6594.709
# 2                             -0.934                          6524.198
# 3                             -1.627                          5944.336
# 4                             -2.817                          6074.551

# %%
#loads the climate data
climateTable = np.genfromtxt('tempData.txt', skip_header=2)
#table is an matrix [year, month(1-12), monthly anomaly]
climateTable

#dataframe representing the climate data
climate_df = pd.DataFrame(climateTable, columns=['Year', 'Month', 'Monthly Anomaly', 'Monthly Uncertainty', 'Annual Anomaly', 'Annual Uncertainty', 'Five Year Anomaly', 'Five Year Uncertainty', 'Ten Year Anomaly', 'Ten Year Uncertainty', 'Twenty Year Anomaly', 'Twenty Year Uncertainty'])
climate_df.head(5)
# Out:
#      Year  Month  Monthly Anomaly  Monthly Uncertainty  Annual Anomaly  \
# 0  1768.0    9.0           -0.850                2.880             NaN
# 1  1768.0   10.0           -1.578                3.386             NaN
# 2  1768.0   11.0           -1.199                3.783          -0.471
# 3  1768.0   12.0           -0.522                4.979          -0.204
# 4  1769.0    1.0            0.118                4.856          -0.088
#
#    Annual Uncertainty  Five Year Anomaly  Five Year Uncertainty  \
# 0                 NaN                NaN                    NaN
# 1                 NaN                NaN                    NaN
# 2               2.380                NaN                    NaN
# 3               2.390                NaN                    NaN
# 4               2.325                NaN                    NaN
#
#    Ten Year Anomaly  Ten Year Uncertainty  Twenty Year Anomaly  \
# 0               NaN                   NaN                  NaN
# 1               NaN                   NaN                  NaN
# 2               NaN                   NaN                  NaN
# 3               NaN                   NaN                  NaN
# 4               NaN                   NaN                  NaN
#
#    Twenty Year Uncertainty
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
#gets the climate data from 1973 and on
climate_data = climate_df[climate_df['Year'] >= 1973]

#creates a new column in the format of year-month-day
climate_data['Day'] = 1
date = climate_data[['Year', 'Month', 'Day']].copy()
date = pd.to_datetime(date)
climate_data['Date'] = date

#drops the old date columns
climate_data = climate_data.drop('Year', axis=1)
climate_data = climate_data.drop('Month', axis=1)
climate_data = climate_data.drop('Day', axis=1)

#rearranges the columns
climate_data = climate_data[['Date', 'Monthly Anomaly', 'Monthly Uncertainty', 'Annual Anomaly',
       'Annual Uncertainty', 'Five Year Anomaly', 'Five Year Uncertainty',
       'Ten Year Anomaly', 'Ten Year Uncertainty', 'Twenty Year Anomaly',
       'Twenty Year Uncertainty']]

climate_data.head(5)
# Out:
# /home/harrison/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/harrison/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#            Date  Monthly Anomaly  Monthly Uncertainty  Annual Anomaly  \
# 2452 1973-01-01           -0.470                0.297          -0.266
# 2453 1973-02-01            0.130                0.246          -0.263
# 2454 1973-03-01            1.555                0.279          -0.244
# 2455 1973-04-01           -0.842                0.178          -0.124
# 2456 1973-05-01           -0.408                0.313          -0.012
#
#       Annual Uncertainty  Five Year Anomaly  Five Year Uncertainty  \
# 2452               0.054             -0.177                  0.047
# 2453               0.046             -0.189                  0.041
# 2454               0.049             -0.198                  0.038
# 2455               0.046             -0.172                  0.036
# 2456               0.050             -0.181                  0.035
#
#       Ten Year Anomaly  Ten Year Uncertainty  Twenty Year Anomaly  \
# 2452            -0.101                 0.024               -0.017
# 2453            -0.114                 0.024               -0.012
# 2454            -0.123                 0.025               -0.013
# 2455            -0.115                 0.026               -0.021
# 2456            -0.108                 0.026               -0.027
#
#       Twenty Year Uncertainty
# 2452                    0.025
# 2453                    0.024
# 2454                    0.024
# 2455                    0.024
# 2456                    0.023

# %%
#merges the two dataframes on the date
climate_energy_data = pd.merge(energy_data, climate_data, left_on = 'Month', right_on = 'Date')

#Need to check all of the column names the month and date columns seem to be repeated
#print(climate_energy_data['Date'])
climate_energy_data.head(5)
# Out:
#        Month  Primary Energy Consumed by the Residential Sector  \
# 0 1973-01-01                                           1313.816
# 1 1973-02-01                                           1150.011
# 2 1973-03-01                                            970.362
# 3 1973-04-01                                            709.631
# 4 1973-05-01                                            544.596
#
#    Total Energy Consumed by the Residential Sector  \
# 0                                         1932.187
# 1                                         1687.255
# 2                                         1497.067
# 3                                         1177.661
# 4                                         1015.008
#
#    Primary Energy Consumed by the Commercial Sector  \
# 0                                           656.607
# 1                                           621.766
# 2                                           490.154
# 3                                           362.003
# 4                                           289.109
#
#    Total Energy Consumed by the Commercial Sector  \
# 0                                        1079.310
# 1                                        1001.920
# 2                                         884.437
# 3                                         735.461
# 4                                         696.114
#
#    Primary Energy Consumed by the Industrial Sector  \
# 0                                          2054.675
# 1                                          1869.459
# 2                                          1944.295
# 3                                          1924.207
# 4                                          2070.447
#
#    Total Energy Consumed by the Industrial Sector  \
# 0                                        2701.524
# 1                                        2460.752
# 2                                        2579.613
# 3                                        2550.210
# 4                                        2741.810
#
#    Primary Energy Consumed by the Transportation Sector  \
# 0                                           1506.380
# 1                                           1439.361
# 2                                           1561.162
# 3                                           1479.971
# 4                                           1621.585
#
#    Total Energy Consumed by the Transportation Sector  \
# 0                                           1509.552
# 1                                           1442.127
# 2                                           1564.016
# 3                                           1482.632
# 4                                           1624.436
#
#    Primary Energy Consumed by the Electric Power Sector  \
# 0                                           1691.096
# 1                                           1511.458
# 2                                           1559.159
# 3                                           1470.152
# 4                                           1551.631
#
#             ...             Monthly Anomaly  Monthly Uncertainty  \
# 0           ...                      -0.470                0.297
# 1           ...                       0.130                0.246
# 2           ...                       1.555                0.279
# 3           ...                      -0.842                0.178
# 4           ...                      -0.408                0.313
#
#   Annual Anomaly  Annual Uncertainty  Five Year Anomaly  \
# 0         -0.266               0.054             -0.177
# 1         -0.263               0.046             -0.189
# 2         -0.244               0.049             -0.198
# 3         -0.124               0.046             -0.172
# 4         -0.012               0.050             -0.181
#
#    Five Year Uncertainty  Ten Year Anomaly  Ten Year Uncertainty  \
# 0                  0.047            -0.101                 0.024
# 1                  0.041            -0.114                 0.024
# 2                  0.038            -0.123                 0.025
# 3                  0.036            -0.115                 0.026
# 4                  0.035            -0.108                 0.026
#
#    Twenty Year Anomaly  Twenty Year Uncertainty
# 0               -0.017                    0.025
# 1               -0.012                    0.024
# 2               -0.013                    0.024
# 3               -0.021                    0.024
# 4               -0.027                    0.023
#
# [5 rows x 23 columns]
